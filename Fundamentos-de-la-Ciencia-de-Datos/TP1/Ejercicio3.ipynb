# %%
import math


radio = int(input("Introduzca el radio del circulo: "))
area = pow(radio, 2)*math.pi
print(f"El area de el circulo es: {area}")
# Out:
# El area de el circulo es: 153.93804002589985
